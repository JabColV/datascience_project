# %%
import pandas as pd
import yaml
from sqlalchemy import create_engine

# %% [markdown]
# ## Database Connection jac08

# %%
with open('config.yml', 'r') as f: #Abrir el archivo en modo de  lectura
    config = yaml.safe_load(f) # Crear un diccionario con lo que hay en el archivo
    config_db_etl = config['bodega'] #Obtener solo la configuración de la bodega
    config_db = config["fuente"] #Obtener solo la configuración de la bodega

# %%
# Construct the database URL
url_db_etl = (f"{config_db_etl['driver']}://{config_db_etl['user']}:{config_db_etl['password']}@{config_db_etl['host']}:"
           f"{config_db_etl['port']}/{config_db_etl['db']}")
url_db = (f"{config_db['driver']}://{config_db['user']}:{config_db['password']}@{config_db['host']}:"
           f"{config_db['port']}/{config_db['db']}")

# %%
# Create the SQLAlchemy Engine
etl_conn = create_engine(url_db_etl)
olap_conn = create_engine(url_db)

# %% [markdown]
# ## Extraction

# %%
cliente = pd.read_sql_table('dim_cliente', etl_conn)
mensajero = pd.read_sql_table('dim_mensajero', etl_conn)
tiempo = pd.read_sql_table('dim_tiempo', etl_conn)
servicio = pd.read_sql_table("mensajeria_servicio",url_db)

# %%
total_nan = servicio.isna().sum()
print(total_nan)
# Out:
# id                                    0
# descripcion                           0
# nombre_solicitante                    0
# fecha_solicitud                       0
# hora_solicitud                        0
# fecha_deseada                         6
# hora_deseada                          0
# nombre_recibe                         0
# telefono_recibe                       0
# descripcion_pago                    260
# ida_y_regreso                         0
# activo                                0
# novedades                           336
# cliente_id                            0
# destino_id                            0
# mensajero_id                        727
# origen_id                             0
# tipo_pago_id                          0
# tipo_servicio_id                      0
# tipo_vehiculo_id                      0
# usuario_id                            0
# prioridad                             0
# ciudad_destino_id                     0
# ciudad_origen_id                      0
# hora_visto_por_mensajero          28428
# visto_por_mensajero                 336
# descripcion_multiples_origenes      760
# mensajero2_id                     26197
# mensajero3_id                     28145
# multiples_origenes                    0
# asignar_mensajero                     0
# es_prueba                             0
# descripcion_cancelado               346
# dtype: int64

# %%
print(len(servicio))
# Out:
# 28430

# %%
servicio.head(5)
# Out:
#    id                   descripcion nombre_solicitante fecha_solicitud  \
# 0  34  recoger muestras a las 10 am           chat_GPT      2023-10-26
# 1  35              Recogervmx a las           chat_GPT      2023-10-26
# 2  36         recoger mx a las 9 am           chat_GPT      2023-10-28
# 3  41        recoger mx a las 11 am           chat_GPT      2023-11-07
# 4  42        recoger mx a las 11 am           chat_GPT      2023-11-07
#
#   hora_solicitud fecha_deseada hora_deseada nombre_recibe telefono_recibe  \
# 0       09:46:03    2023-10-26     09:46:03        Gemini             100
# 1       11:18:14    2023-10-26     11:18:14        Gemini             100
# 2       19:21:01    2023-10-30     19:21:01        Gemini             100
# 3       09:46:09    2023-11-07     09:46:09        Gemini             100
# 4       09:46:10    2023-11-07     09:46:10        Gemini             100
#
#   descripcion_pago  ...  ciudad_origen_id  hora_visto_por_mensajero  \
# 0                   ...                 1                      None
# 1                   ...                 1                      None
# 2                   ...                 1                      None
# 3                   ...                 1                      None
# 4                   ...                 1                      None
#
#   visto_por_mensajero  descripcion_multiples_origenes  mensajero2_id  \
# 0                                                                NaN
# 1                                                                NaN
# 2                                                                NaN
# 3                                                                NaN
# 4                                                                NaN
#
#    mensajero3_id  multiples_origenes  asignar_mensajero  es_prueba  \
# 0            NaN               False               True      False
# 1            NaN               False              False       True
# 2            NaN               False               True      False
# 3            NaN               False               True      False
# 4            NaN               False               True      False
#
#    descripcion_cancelado
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 33 columns]

# %% [markdown]
# ## Transformation

# %%
tiempo_unique = tiempo[["month_year", "key_tiempo"]].drop_duplicates(subset=["month_year"])

servicio["año_mes"] = servicio["fecha_solicitud"].dt.to_period("M").astype(str)
servicio = servicio[["id", "año_mes", "cliente_id", "mensajero_id"]]
servicio.fillna(-1, inplace=True)
# Hacer el merge asegurando que coincidan
hecho_servicio_mensual = pd.merge(servicio, tiempo_unique[["month_year", "key_tiempo"]], left_on="año_mes", right_on="month_year", how="left")
hecho_servicio_mensual.head(5)
# Out:
#    id  año_mes  cliente_id  mensajero_id month_year  key_tiempo
# 0  34  2023-10           5          -1.0    2023-10        6360
# 1  35  2023-10           5           7.0    2023-10        6360
# 2  36  2023-10           5          -1.0    2023-10        6360
# 3  41  2023-11           5          -1.0    2023-11        7104
# 4  42  2023-11           5          -1.0    2023-11        7104

# %%
hecho_servicio_mensual = pd.merge(hecho_servicio_mensual, cliente[["cliente_id", "key_cliente"]], left_on="cliente_id", right_on="cliente_id", how="left")
hecho_servicio_mensual.head(5)
# Out:
#    id  año_mes  cliente_id  mensajero_id month_year  key_tiempo  key_cliente
# 0  34  2023-10           5          -1.0    2023-10        6360            7
# 1  35  2023-10           5           7.0    2023-10        6360            7
# 2  36  2023-10           5          -1.0    2023-10        6360            7
# 3  41  2023-11           5          -1.0    2023-11        7104            7
# 4  42  2023-11           5          -1.0    2023-11        7104            7

# %%
mensajero.rename(columns={'id':'mensajero_id'}, inplace=True)
hecho_servicio_mensual = hecho_servicio_mensual.merge(mensajero[["mensajero_id", "key_mensajero"]], left_on="mensajero_id", right_on="mensajero_id", how="left")
hecho_servicio_mensual.fillna(-1, inplace=True)
hecho_servicio_mensual.head(5)
# Out:
#    id  año_mes  cliente_id  mensajero_id month_year  key_tiempo  key_cliente  \
# 0  34  2023-10           5          -1.0    2023-10        6360            7
# 1  35  2023-10           5           7.0    2023-10        6360            7
# 2  36  2023-10           5          -1.0    2023-10        6360            7
# 3  41  2023-11           5          -1.0    2023-11        7104            7
# 4  42  2023-11           5          -1.0    2023-11        7104            7
#
#    key_mensajero
# 0           -1.0
# 1           13.0
# 2           -1.0
# 3           -1.0
# 4           -1.0

# %%
print(len(hecho_servicio_mensual))
# Out:
# 28430

# %% [markdown]
# ## Cálculo del atributo solicitudes_por_mes

# %%
# Contar solicitudes por cada 'año_mes'
solicitudes_por_mes = hecho_servicio_mensual.groupby("año_mes").size().reset_index(name="solicitud_por_mes")
# Hacer merge para agregar la columna 'solicitud_por_mes' al DataFrame original
hecho_servicio_mensual = hecho_servicio_mensual.merge(solicitudes_por_mes, on="año_mes", how="left")
hecho_servicio_mensual.head(50)
# 11            7           -1.0                 12
# 12            7           -1.0                 12
# 13            7           13.0                 12
# 14            7           13.0                 12
# 15            7           13.0                 12
# 16            7           13.0                 21
# 17            7           13.0                 21
# 18            7           13.0                 21
# 19            7           24.0                 17
# 20            7           -1.0                 17
# 21            7           -1.0                 17
# 22            7           13.0                 25
# 23            7           13.0                296
# 24            7           13.0                 17
# 25            7           13.0                 25
# 26            7           13.0                 17
# 27            7           13.0                 25
# 28            1           13.0               2479
# 29            7           13.0                 25
# 30            7           13.0                 25
# 31            7           13.0                 25
# 32            7           13.0                 25
# 33            7           -1.0                 17
# 34            7           -1.0                 12
# 35           11           39.0                 25
# 36            7           13.0                 25
# 37            7           13.0                 17
# 38            7           13.0                 25
# 39            7           24.0                 17
# 40           11           39.0                 25
# 41           11           39.0                 25
# 42            7           13.0                296
# 43           11           39.0                 25
# 44           11           39.0                 25
# 45            6           24.0                 25
# 46            7           13.0                 25
# 47            7           -1.0                 25
# 48            7           13.0                 25
# 49            7           13.0                296

# %%
print(len(hecho_servicio_mensual))
# Out:
# 28430

# %% [markdown]
# ## Cálculo del atributo solicitudes_por_mes_cliente

# %%
# Contar solicitudes por cada 'key_tiempo' y 'key_cliente' 
solicitud_por_mes_cliente = hecho_servicio_mensual.groupby(["key_tiempo","key_cliente"]).size().reset_index(name="solicitud_por_mes_cliente")
# Hacer merge para agregar la columna 'solicitud_por_mes' al DataFrame original
hecho_servicio_mensual = hecho_servicio_mensual.merge(solicitud_por_mes_cliente, on=["key_cliente", "key_tiempo"], how="left")
hecho_servicio_mensual.head(5)
# Out:
#    id  año_mes  cliente_id  mensajero_id month_year  key_tiempo  key_cliente  \
# 0  34  2023-10           5          -1.0    2023-10        6360            7
# 1  35  2023-10           5           7.0    2023-10        6360            7
# 2  36  2023-10           5          -1.0    2023-10        6360            7
# 3  41  2023-11           5          -1.0    2023-11        7104            7
# 4  42  2023-11           5          -1.0    2023-11        7104            7
#
#    key_mensajero  solicitud_por_mes  solicitud_por_mes_cliente
# 0           -1.0                 12                         12
# 1           13.0                 12                         12
# 2           -1.0                 12                         12
# 3           -1.0                 17                         16
# 4           -1.0                 17                         16

# %%
print(len(hecho_servicio_mensual))
# Out:
# 28430

# %% [markdown]
# ## Cálculo del atributo solicitudes_por_mensajero

# %%
# Contar solicitudes por cada 'key_tiempo' y 'key_mensajero'
cantidad_solicitud_por_mensajero = hecho_servicio_mensual.groupby(["key_mensajero"]).size().reset_index(name="cantidad_solicitud_por_mensajero")
# Hacer merge para agregar la columna 'solicitud_por_mes' al DataFrame original
hecho_servicio_mensual = hecho_servicio_mensual.merge(cantidad_solicitud_por_mensajero, on=["key_mensajero"], how="left")
hecho_servicio_mensual.head(50)
# Out:
#      id  año_mes  cliente_id  mensajero_id month_year  key_tiempo  \
# 0    34  2023-10           5          -1.0    2023-10        6360
# 1    35  2023-10           5           7.0    2023-10        6360
# 2    36  2023-10           5          -1.0    2023-10        6360
# 16            7           13.0                 21                         18
# 17            7           13.0                 21                         18
# 18            7           13.0                 21                         18
# 19            7           24.0                 17                         16
# 20            7           -1.0                 17                         16
# 21            7           -1.0                 17                         16
# 22            7           13.0                 25                         19
# 23            7           13.0                296                         91
# 24            7           13.0                 17                         16
# 25            7           13.0                 25                         19
# 26            7           13.0                 17                         16
# 27            7           13.0                 25                         19
# 28            1           13.0               2479                         16
# 29            7           13.0                 25                         19
# 30            7           13.0                 25                         19
# 31            7           13.0                 25                         19
# 32            7           13.0                 25                         19
# 33            7           -1.0                 17                         16
# 34            7           -1.0                 12                         12
# 35           11           39.0                 25                          5
# 36            7           13.0                 25                         19
# 37            7           13.0                 17                         16
# 38            7           13.0                 25                         19
# 39            7           24.0                 17                         16
# 40           11           39.0                 25                          5
# 41           11           39.0                 25                          5
# 42            7           13.0                296                         91
# 43           11           39.0                 25                          5
# 44           11           39.0                 25                          5
# 45            6           24.0                 25                          1
# 46            7           13.0                 25                         19
# 47            7           -1.0                 25                         19
# 48            7           13.0                 25                         19
# 49            7           13.0                296                         91
#
#     cantidad_solicitud_por_mensajero
# 0                                727
# 1                                 68
# 2                                727
# 3                                727
# 4                                727
# 5                                727
# 6                                436
# 7                                436
# 8                                436
# 9                                727
# 10                               727
# 11                               727
# 12                               727
# 13                                68
# 14                                68
# 15                                68
# 16                                68
# 17                                68
# 18                                68
# 19                               436
# 20                               727
# 21                               727
# 22                                68
# 23                                68
# 24                                68
# 25                                68
# 26                                68
# 27                                68
# 28                                68
# 29                                68
# 30                                68
# 31                                68
# 32                                68
# 33                               727
# 34                               727
# 35                               917
# 36                                68
# 37                                68
# 38                                68
# 39                               436
# 40                               917
# 41                               917
# 42                                68
# 43                               917
# 44                               917
# 45                               436
# 46                                68
# 47                               727
# 48                                68
# 49                                68

# %% [markdown]
# ## Eliminar filas no necesarias

# %%
hecho_servicio_mensual.drop(columns=["id","cliente_id","año_mes","mensajero_id","month_year"], inplace=True)
hecho_servicio_mensual
# Out:
#        key_tiempo  key_cliente  key_mensajero  solicitud_por_mes  \
# 0            6360            7           -1.0                 12
# 1            6360            7           13.0                 12
# 2            6360            7           -1.0                 12
# 3            7104            7           -1.0                 17
# 4            7104            7           -1.0                 17
# ...           ...          ...            ...                ...
# 28425       13680           11            8.0               4304
# 28426       13680           11           27.0               4304
# 28427       13680            7           32.0               4304
# 28428       13680           11           18.0               4304
# 28429       13680           11            3.0               4304
#
#        solicitud_por_mes_cliente  cantidad_solicitud_por_mensajero
# 0                             12                               727
# 1                             12                                68
# 2                             12                               727
# 3                             16                               727
# 4                             16                               727
# ...                          ...                               ...
# 28425                       2782                              1059
# 28426                       2782                              1252
# 28427                        628                              2439
# 28428                       2782                                73
# 28429                       2782                              1329
#
# [28430 rows x 6 columns]

# %% [markdown]
# ## Loading

# %%
hecho_servicio_mensual.to_sql("hecho_servicio_mensual", etl_conn, if_exists="replace", index_label="key_solicitud_servicio")
# Out:
# 430
