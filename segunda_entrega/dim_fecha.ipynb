# %%
from datetime import datetime
import pandas as pd
import yaml
from sqlalchemy import create_engine

# %%
with open('config.yml', 'r') as f: #Abrir el archivo en modo de  lectura
    config = yaml.safe_load(f) # Crear un diccionario con lo que hay en el archivo
    config_db_etl = config['bodega'] #Obtener solo la configuración de la bodega

# %%
# Construct the database URL
url_db_etl = (f"{config_db_etl['driver']}://{config_db_etl['user']}:{config_db_etl['password']}@{config_db_etl['host']}:"
           f"{config_db_etl['port']}/{config_db_etl['db']}")

# %%
# Create the SQLAlchemy Engine
etl_conn = create_engine(url_db_etl)

# %%
fecha = pd.DataFrame({"date": pd.date_range(start="1/09/2023",end="31/12/2024",freq="d")})
fecha
# Out:
#           date
# 0   2023-01-09
# 1   2023-01-10
# 2   2023-01-11
# 3   2023-01-12
# 4   2023-01-13
# ..         ...
# 718 2024-12-27
# 719 2024-12-28
# 720 2024-12-29
# 721 2024-12-30
# 722 2024-12-31
#
# [723 rows x 1 columns]

# %%
fecha["year"] = fecha["date"].dt.year
fecha["month_year"] = fecha["date"].dt.to_period("M").astype(str)
fecha["month"] = fecha["date"].dt.month
fecha["day"] = fecha["date"].dt.day
fecha["month_str"] = fecha["date"].dt.month_name()  
fecha["day_str"] = fecha["date"].dt.day_name()  
fecha["saved"] = datetime.today()
fecha
# Out:
#           date  year month_year  month  day month_str    day_str  \
# 0   2023-01-09  2023    2023-01      1    9   January     Monday
# 1   2023-01-10  2023    2023-01      1   10   January    Tuesday
# 2   2023-01-11  2023    2023-01      1   11   January  Wednesday
# 3   2023-01-12  2023    2023-01      1   12   January   Thursday
# 4   2023-01-13  2023    2023-01      1   13   January     Friday
# ..         ...   ...        ...    ...  ...       ...        ...
# 718 2024-12-27  2024    2024-12     12   27  December     Friday
# 719 2024-12-28  2024    2024-12     12   28  December   Saturday
# 720 2024-12-29  2024    2024-12     12   29  December     Sunday
# 721 2024-12-30  2024    2024-12     12   30  December     Monday
# 722 2024-12-31  2024    2024-12     12   31  December    Tuesday
#
#                          saved
# 0   2024-11-05 18:46:34.661297
# 1   2024-11-05 18:46:34.661297
# 2   2024-11-05 18:46:34.661297
# 3   2024-11-05 18:46:34.661297
# 4   2024-11-05 18:46:34.661297
# ..                         ...
# 718 2024-11-05 18:46:34.661297
# 719 2024-11-05 18:46:34.661297
# 720 2024-11-05 18:46:34.661297
# 721 2024-11-05 18:46:34.661297
# 722 2024-11-05 18:46:34.661297
#
# [723 rows x 8 columns]

# %% [markdown]
# ## Load table into ETL database

# %%
fecha.to_sql("dim_fecha", etl_conn, index_label="key_fecha", if_exists="replace")
# Out:
# 723
